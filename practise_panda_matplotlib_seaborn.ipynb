# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('5/15/2020', periods = 1000), columns = ['value'])
df.head()
# Out:
#                value
# 2020-05-15 -0.499629
# 2020-05-16  1.379523
# 2020-05-17 -0.038696
# 2020-05-18  0.738820
# 2020-05-19 -0.727709

# %%
ts = pd.Series(randn(1000), index = pd.date_range('5/15/2020', periods = 1000))
ts.head()
# Out:
# 2020-05-15   -2.418144
# 2020-05-16    0.483249
# 2020-05-17    0.529663
# 2020-05-18   -0.269411
# 2020-05-19   -0.788523
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2020-05-15 -0.499629
# 2020-05-16  0.879894
# 2020-05-17  0.841198
# 2020-05-18  1.580018
# 2020-05-19  0.852309

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2020-05-15   -2.418144
# 2020-05-16   -1.934895
# 2020-05-17   -1.405232
# 2020-05-18   -1.674642
# 2020-05-19   -2.463166
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize = (5,5))

# %%
df.plot(figsize = (5,5))

# %%
plt.plot(ts)

# %%
plt.plot(df)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize = (15,8), title = 'iris dataset')
ax.set_label('X label')
ax.set_label('Y label')

# %%
iris.plot(kind='bar')

# %%
ts.plot('bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
#   """Entry point for launching an IPython kernel.

# %%
df_iris = iris.drop('species', axis=1)
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df_iris.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df_iris.iloc[0].plot(kind = 'bar')

# %%
df_iris.iloc[1].plot.bar()

# %%
df_iris.plot.hist()

# %%
df_iris.plot.hist(stacked = False, bins = 100)

# %%
df_iris.plot(kind = 'hist',stacked = False, bins = 100)

# %%
df_iris.plot(kind = 'hist',stacked = False, bins = 100, orientation = 'horizontal')

# %%
df_iris.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df_iris['sepal_length'].diff().head()
# Out:
# 0    NaN
# 1   -0.2
# 2   -0.2
# 3   -0.1
# 4    0.4
# Name: sepal_length, dtype: float64

# %%
df_iris.diff().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5ABF0D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5C0082C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5C082F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5D0A20C8>]],
#       dtype=object)

# %%
df_iris.diff().hist(color = 'orange', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5D4F3308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5D9A2888>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5D9D1FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B5DA0BA08>]],
#       dtype=object)

# %%
df_iris.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df_iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c= 'sepal_width')

# %%
df_iris.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')

# %%
df_iris.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width',ax = ax, color = 'r')

# %%
df_iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 100)

# %%
df_iris.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 20, C = 'sepal_width')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot.bar()

# %%
df_new = pd.DataFrame(randn(10,4), columns = ['a','b','c','d'])
df_new
# Out:
#           a         b         c         d
# 0  1.298794  0.752014  0.479102  1.573973
# 1 -0.175049  1.023557  0.653882 -1.425883
# 2 -0.131309  0.093268 -0.787751  1.050684
# 3  1.253321  0.862373  0.297266 -0.535758
# 4 -0.550441  1.280316 -0.875582  1.057526
# 5  0.332455  0.574799  0.358087  1.281230
# 6  0.934184 -0.416179 -0.273271  1.245709
# 7 -1.716111 -0.620653  0.235728 -0.731205
# 8 -0.429965  1.764613  0.060434  0.739845
# 9  0.733515  0.451522  1.041584 -1.163685

# %%
df_new.iloc[0].plot.bar()

# %%
df_new.plot.bar()

# %%
df_new.plot.barh()

# %%
df_iris.iloc[0].plot.pie(figsize=(6,6))

# %%
d = pd.DataFrame(randint(1,100), columns=['a','b','c','d'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-fb718142d1a8> in <module>
# ----> 1 d = pd.DataFrame(randint(1,100), columns=['a','b','c','d'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     483                 )
#     484             else:
# --> 485                 raise ValueError("DataFrame constructor not properly called!")
#     486
#     487         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df_iris.iloc[0:4].plot.pie(subplots = True, figsize = (20, 20), fontsize = 10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017B62F16708>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B62F379C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B6301D308>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017B62FC1EC8>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df_iris, figsize= (8,8), diagonal='kde', color = 'orange')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves
andrews_curves(df_iris, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df_iris.plot(legend = True, figsize = (10, 5), logy = True)

# %%
from numpy.random import randn
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0  0.639919
# 1     1  0.649613
# 2     2  0.741556
# 3     3  0.958651
# 4     4 -0.065105

# %%
df_time = pd.DataFrame(dict(time = pd.date_range('5/15/2020', periods = 500), value = randn(500).cumsum()))
df_time.head()
# Out:
#         time     value
# 0 2020-05-15  0.319823
# 1 2020-05-16  0.212685
# 2 2020-05-17 -0.428534
# 3 2020-05-18  0.179125
# 4 2020-05-19  0.242757

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
d = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ['time', 'value'])
d.head()
# Out:
#        time     value
# 0  0.319637 -0.135206
# 1 -0.896042  1.531039
# 2 -0.175195  2.121400
# 3  0.180389  2.010216
# 4  1.101094  3.866172

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = d, sort = True)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
g = sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
g.fig.autofmt_xdate()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap=3, height=3)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 'sd', err_style='bars')

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.catplot(y = 'day', x = 'total_bill', data = tips)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind = 'swarm', hue = 'size')

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['No', 'Yes'])

# %%
sns.catplot(x = 'day', y = 'tip', kind = 'box', data = tips, hue = 'sex')

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds.sort_values('color'))
