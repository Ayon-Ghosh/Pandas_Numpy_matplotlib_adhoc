# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df=pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
df.head()
# Out:
#                value
# 2019-06-07 -0.610616
# 2019-06-08  1.948477
# 2019-06-09  0.167028
# 2019-06-10 -1.331436
# 2019-06-11 -0.179560

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
ts
# Out:
# 2019-06-07    0.215420
# 2019-06-08    0.449254
# 2019-06-09   -0.831729
# 2019-06-10   -0.950121
# 2019-06-11    0.094719
#                 ...
# 2022-02-26    1.308130
# 2022-02-27    1.085313
# 2022-02-28   -0.760971
# 2022-03-01   -0.628422
# 2022-03-02    0.932678
# Freq: D, Length: 1000, dtype: float64

# %%
pd.date_range('2019-06-07', periods = 1000)
# Out:
# DatetimeIndex(['2019-06-07', '2019-06-08', '2019-06-09', '2019-06-10',
#                '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14',
#                '2019-06-15', '2019-06-16',
#                ...
#                '2022-02-21', '2022-02-22', '2022-02-23', '2022-02-24',
#                '2022-02-25', '2022-02-26', '2022-02-27', '2022-02-28',
#                '2022-03-01', '2022-03-02'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.610616
# 2019-06-08  1.337861
# 2019-06-09  1.504889
# 2019-06-10  0.173453
# 2019-06-11 -0.006106

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.215420
# 2019-06-08    0.664674
# 2019-06-09   -0.167054
# 2019-06-10   -1.117175
# 2019-06-11   -1.022456
# Freq: D, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
figsize=(5,5)
ts.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = iris.drop(['species'], axis=1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0 -1.892284  0.747432 -0.420378 -2.099512
# 1  1.113621 -0.977849 -0.870471  2.151805
# 2 -0.517615 -0.944896  1.845111  0.695823
# 3  0.938957 -0.943717 -0.662375  0.142309
# 4 -0.095062  1.602334 -0.614372  1.452752

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.3, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}, xlabel='sepal_width', ylabel='petal_width'>

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
import pandas as pd
import numpy as np
df=pd.Series(np.arange(1,51))
df.ndim
# Out:
# 1

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1)]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'even':pd.Series(np.arange(0,100,2)),'odd':pd.Series(np.arange(1,100,2))})
#df
#print(df['odd'])
#print(df['even'])
print(df.sum())
# Out:
# even    2450
# odd     2500
# dtype: int64

# %%
import pandas as pd
import numpy as np
world_cup = {'Team':['WI','WI','IND','AUS','PAK','SRK','AUS','AUS','AUS','IND','AUS'],'Rank':[7,7,2,1,6,4,1,1,1,2,2],'Year':[1975,1979,1983,1987,1991,1995,1999,2003,2007,2011,2015]}
match_stats = {'Team':['WI','IND','PAK','SRK','AUS'],'WC_played':[11,11,9,8,10],'ODI':[733,988,712,678,700]}
df1 = pd.DataFrame(world_cup)  
df1
# Out:
#    Team  Rank  Year
# 0    WI     7  1975
# 1    WI     7  1979
# 2   IND     2  1983
# 3   AUS     1  1987
# 4   PAK     6  1991
# 5   SRK     4  1995
# 6   AUS     1  1999
# 7   AUS     1  2003
# 8   AUS     1  2007
# 9   IND     2  2011
# 10  AUS     2  2015

# %%
df2 = pd.DataFrame(match_stats)
df2
# Out:
#   Team  WC_played  ODI
# 0   WI         11  733
# 1  IND         11  988
# 2  PAK          9  712
# 3  SRK          8  678
# 4  AUS         10  700

# %%
print(df1.append(df2,sort=True))
# Out:
#       ODI  Rank Team  WC_played    Year
# 0     NaN   7.0   WI        NaN  1975.0
# 1     NaN   7.0   WI        NaN  1979.0
# 2     NaN   2.0  IND        NaN  1983.0
# 3     NaN   1.0  AUS        NaN  1987.0
# 4     NaN   6.0  PAK        NaN  1991.0
# 5     NaN   4.0  SRK        NaN  1995.0
# 6     NaN   1.0  AUS        NaN  1999.0
# 7     NaN   1.0  AUS        NaN  2003.0
# 8     NaN   1.0  AUS        NaN  2007.0
# 9     NaN   2.0  IND        NaN  2011.0
# 10    NaN   2.0  AUS        NaN  2015.0
# 0   733.0   NaN   WI       11.0     NaN
# 1   988.0   NaN  IND       11.0     NaN
# 2   712.0   NaN  PAK        9.0     NaN
# 3   678.0   NaN  SRK        8.0     NaN
# 4   700.0   NaN  AUS       10.0     NaN

# %%
print(pd.merge(df1,df2,on='Team'))
# Out:
#    Team  Rank  Year  WC_played  ODI
# 0    WI     7  1975         11  733
# 1    WI     7  1979         11  733
# 2   IND     2  1983         11  988
# 3   IND     2  2011         11  988
# 4   AUS     1  1987         10  700
# 5   AUS     1  1999         10  700
# 6   AUS     1  2003         10  700
# 7   AUS     1  2007         10  700
# 8   AUS     2  2015         10  700
# 9   PAK     6  1991          9  712
# 10  SRK     4  1995          8  678

# %%
print(pd.merge(df1,df2,on='Team',how='left'))
# Out:
#    Team  Rank  Year  WC_played  ODI
# 0    WI     7  1975         11  733
# 1    WI     7  1979         11  733
# 2   IND     2  1983         11  988
# 3   AUS     1  1987         10  700
# 4   PAK     6  1991          9  712
# 5   SRK     4  1995          8  678
# 6   AUS     1  1999         10  700
# 7   AUS     1  2003         10  700
# 8   AUS     1  2007         10  700
# 9   IND     2  2011         11  988
# 10  AUS     2  2015         10  700

# %%
print(pd.merge(df1,df2,on='Team',how='right'))
# Out:
#    Team  Rank  Year  WC_played  ODI
# 0    WI     7  1975         11  733
# 1    WI     7  1979         11  733
# 2   IND     2  1983         11  988
# 3   IND     2  2011         11  988
# 4   PAK     6  1991          9  712
# 5   SRK     4  1995          8  678
# 6   AUS     1  1987         10  700
# 7   AUS     1  1999         10  700
# 8   AUS     1  2003         10  700
# 9   AUS     1  2007         10  700
# 10  AUS     2  2015         10  700

# %%
print(pd.merge(df1,df2,on='Team',how='outer'))
# Out:
#    Team  Rank  Year  WC_played  ODI
# 0    WI     7  1975         11  733
# 1    WI     7  1979         11  733
# 2   IND     2  1983         11  988
# 3   IND     2  2011         11  988
# 4   AUS     1  1987         10  700
# 5   AUS     1  1999         10  700
# 6   AUS     1  2003         10  700
# 7   AUS     1  2007         10  700
# 8   AUS     2  2015         10  700
# 9   PAK     6  1991          9  712
# 10  SRK     4  1995          8  678
